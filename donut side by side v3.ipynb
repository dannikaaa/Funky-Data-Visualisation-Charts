# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
fracs = [15, 30, 45, 10]

fig = plt.figure()

ax1 = fig.add_axes([0, 0, .5, .5], aspect=1)
ax1.pie(fracs, labels=labels, radius = 1.2)
ax2 = fig.add_axes([.5, .0, .5, .5], aspect=1)
ax2.pie(fracs, labels=labels, radius = 1.2)
ax1.set_title('Title for ax1', y=1.2)
ax2.set_title('Title for ax2', y=1.2)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["flour",
          "sugar",
          "egg",
          "butter",
          "milk",
          "package of yeast"]

data = [225, 90, 50, 60, 100, 5]

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(recipe[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("Matplotlib bakery: A donut")

plt.show()

# %%
recipe = "flour","sugar","egg","butter","milk","yeast"
fracs = [15, 30, 45, 10]
data = [225, 90, 50, 60, 100, 5]

fig = plt.figure()

ax1 = fig.add_axes([0, 0, .5, .5], aspect=1)
ax1.pie(data, labels=recipe, radius = 1.2)
ax2 = fig.add_axes([.5, .0, .5, .5], aspect=1)
ax2.pie(data, labels=recipe, radius = 1.2)
ax1.set_title('A donut', y=1.2)
ax2.set_title('A donut',y=1.2)
plt.show()

# %%
recipe = "flour","sugar","egg","butter","milk","yeast"
fracs = [15, 30, 45, 10]
data = [225, 90, 50, 60, 100, 5]

fig = plt.figure()

ax1 = fig.add_axes([0, 0, .5, .5], aspect=1)
ax1.pie(data, labels=recipe, radius = 1.2)
ax2 = fig.add_axes([.5, .0, .5, .5], aspect=1)
ax2.pie(data, labels=recipe, radius = 1.2)
circle = plt.Circle((0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
ax1.set_title('A donut', y=1.1)
ax2.set_title('A donut',y=1.1)
plt.savefig('donut1.png')
plt.show()

# %%
# libraries
import os
from matplotlib import font_manager as fm, rcParams
import numpy as np
import pandas as pd
import matplotlib

matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10) 

import matplotlib.pyplot as plt
 
# specify the custom font to use
#plt.rcParams['font.family'] = 'sans-serif'
#plt.rcParams['font.sans-serif'] = 'Arial'

#fonts
fpath = os.path.join(rcParams["datapath"], "C:\\Users\\danica\\Documents\\holonIQ\\fonts\\Gilroy-Light.otf")
lpath = os.path.join(rcParams["datapath"], "C:\\Users\\danica\\Documents\\holonIQ\\fonts\\Gilroy-ExtraBold.otf")

prop = fm.FontProperties(fname=fpath)
footnote = fm.FontProperties(fname=fpath)
footnote.set_size(7)
large = fm.FontProperties(fname=lpath)
large.set_size(13)
large.set_weight('bold')

# %%
#establish the subplots
fig, ax = plt.subplots(figsize=(6, 6))

# Set the Chart Titles
title_string = "AI StartUps by Application"
subtitle_string = "Global Expenditure (USD Trillions)"
plt.suptitle(title_string, y=0.925, x=0.125, fontsize=12, fontweight='bold', horizontalalignment='left',fontproperties=large)
plt.title(subtitle_string, fontsize=10, loc='left',fontproperties=prop,y=.97)

# create data
names='Vision', 'Audio', 'NLP', 'Algorithms',
size=[35,24,21,11]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')

# Add footnotes
plt.annotate('Source: China Money Network', (0,0), (0, -5), xycoords='axes fraction', textcoords='offset points', color='black', va='top',fontproperties=footnote)

#plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelright='on', labelbottom='on', color='dimgrey')

# Give color names
plt.pie(size, labels=names, startangle=90, counterclock = False, colors=[(0.745, 0.0980, 0.117),(0.235, 0.694, 0.529, 1),(0.957, 0.765, 0, 1),(0.890, 0.243, 0.380, 1)], wedgeprops = { 'linewidth' : 5, 'edgecolor' : 'white' },textprops=dict(fontproperties=prop,color='black'))
fig1=plt.gcf()
fig1.gca().add_artist(my_circle)
plt.show()
plt.draw()
fig1.savefig('figure3.png', dpi=300,bbox_inches='tight', transparent=False)

# %%
names='Vision', 'Audio', 'NLP', 'Algorithms'
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
size=[35,24,21,11]

my_circle=plt.Circle( (0,0), 0.7, color='white')

fig = plt.figure()

#plt.subplot(1,2,1)
ax1 = fig.add_subplot(1,2,1)
ax1.pie(size, labels=names, startangle=90, counterclock = False, colors=[(0.149, 0.506, 1, 1),(0.235, 0.694, 0.529, 1),(0.957, 0.765, 0, 1),(0.890, 0.243, 0.380, 1)], wedgeprops = { 'linewidth' : 5, 'edgecolor' : 'white' },textprops=dict(fontproperties=prop,color='black'))

fig1=plt.gcf()
fig1.gca().add_artist(my_circle)
#plt.show()
plt.draw()

#plt.subplot(1,2,2)
ax2 = fig.add_subplot(1,2,2)
ax2.pie(size, labels=labels, startangle=90, counterclock = False, colors=[(0.149, 0.506, 1, 1),(0.235, 0.694, 0.529, 1),(0.957, 0.765, 0, 1),(0.890, 0.243, 0.380, 1)], wedgeprops = { 'linewidth' : 5, 'edgecolor' : 'white' },textprops=dict(fontproperties=prop,color='black'))

#fig2=plt.gcf()
#fig2.gca().add_artist(my_circle)
plt.show()
plt.draw()

# %%
names='Vision', 'Audio', 'NLP', 'Algorithms'
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
size=[35,24,21,11]

title_string = "AI StartUps by Application"
subtitle_string = "Global Expenditure"

fig = plt.figure()
fig.suptitle(title_string, fontsize=14, fontweight='bold', y=1.1)
c1 = plt.Circle( (0,0), radius=0.7, color='white')

#ax1 = fig.add_axes([0,0,1,1], aspect=1)
ax1 = fig.add_axes([0.05,0,0.45,1], aspect=1)
ax1.pie(size, labels=names, startangle=30, counterclock=False, 
        colors=[(0.745, 0.0980, 0.1176), (0.30196, 0.6745, 0.8784), (0.9647, 0.5137, 0.1176), (0.0, 0.50588, 0.8392)], 
        wedgeprops = {'linewidth':5, 'edgecolor':'white'}, 
        textprops=dict(fontproperties=prop, color='black'))
ax1.add_patch(c1)
ax1.set_title(title_string, y=1.1, x=0.105, fontsize=13, fontweight='bold', horizontalalignment='left',fontproperties=large)
#ax1.set_title(subtitle_string, fontsize=10, loc='left',fontproperties=prop,y=.97)
ax1.annotate('Source: China Money Network', (0,0), (0, -5), xycoords='axes fraction', textcoords='offset points', color='black', va='top',fontproperties=footnote)

c2 = plt.Circle( (0,0), radius=0.7, color='white')
#ax2 = fig.add_axes([1,0,1,1], aspect=1)
ax2 = fig.add_axes([0.535,0,0.45,1], aspect=1)
ax2.pie(size, labels=labels, startangle=30, counterclock=False, 
        colors=[(0.9921, 0.8078, 0.2078), (0.30196, 0.6745, 0.8784), (0.9647, 0.5137, 0.1176), (0.6274, 0.8078, 0.207)], 
        wedgeprops = {'linewidth':5, 'edgecolor':'white'}, 
        textprops=dict(fontproperties=prop, color='black'))
ax2.add_patch(c2)
ax2.set_title(subtitle_string, y=1.1, x=0.105, fontsize=13, fontweight='bold', horizontalalignment='left',fontproperties=large)
ax2.annotate('Source: China Money Network', (0,0), (0, -5), xycoords='axes fraction', textcoords='offset points', color='black', va='top',fontproperties=footnote)

plt.savefig('side by side with one head title.png')
plt.show()

# %%
#https://stackoverflow.com/questions/51866626/plotting-side-by-side-charts-using-matplotlib-using
#https://stackoverflow.com/questions/42818361/how-to-make-two-plots-side-by-side-using-python

names='Vision', 'Audio', 'NLP', 'Algorithms'
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
size=[35,24,21,11]

title_string = "AI StartUps by Application"
subtitle_string = "Global Expenditure"

fig = plt.figure()
#fig.suptitle(title_string, fontsize=14, fontweight='bold', y=1.1)
c1 = plt.Circle( (0,0), radius=0.7, color='white')

#ax1 = fig.add_axes([0,0,1,1], aspect=1)
ax1 = fig.add_axes([0.05,0,0.45,1], aspect=1)
ax1.pie(size, labels=names, startangle=30, counterclock=False, 
        colors=[(0.745, 0.0980, 0.1176), (0.30196, 0.6745, 0.8784), (0.9647, 0.5137, 0.1176), (0.0, 0.50588, 0.8392)], 
        wedgeprops = {'linewidth':5, 'edgecolor':'white'}, 
        textprops=dict(fontproperties=prop, color='black'))
ax1.add_patch(c1)
ax1.set_title(title_string, y=1.05, x=0.01, fontsize=13, fontweight='bold', horizontalalignment='left',fontproperties=large)
ax1.set_title(subtitle_string, fontsize=10, loc='left',fontproperties=prop,y=.97, x=0.01)
kwargs = dict(size=20, fontweight='bold', va='center',fontproperties=prop)
ax1.text(0, 0, '2018', ha='center', **kwargs, fontsize=25)
ax1.annotate('Source: China Money Network', (0,0), (0, -5), xycoords='axes fraction', textcoords='offset points', color='black', va='top',fontproperties=footnote)

c2 = plt.Circle( (0,0), radius=0.7, color='white')
#ax2 = fig.add_axes([1,0,1,1], aspect=1)
ax2 = fig.add_axes([0.535,0,0.45,1], aspect=1)
ax2.pie(size, labels=labels, startangle=30, counterclock=False, 
        colors=[(0.9921, 0.8078, 0.2078), (0.30196, 0.6745, 0.8784), (0.9647, 0.5137, 0.1176), (0.6274, 0.8078, 0.207)], 
        wedgeprops = {'linewidth':5, 'edgecolor':'white'}, 
        textprops=dict(fontproperties=prop, color='black'))
ax2.add_patch(c2)
ax2.set_title(subtitle_string, y=1.05, x=0.05, fontsize=13, fontweight='bold', horizontalalignment='left',fontproperties=large)
ax2.set_title(title_string, fontsize=10, loc='left',fontproperties=prop,y=.97, x=0.05)
kwargs = dict(size=20, fontweight='bold', va='center',fontproperties=prop)
ax2.text(0, 0, '2025', ha='center', **kwargs, fontsize=25)
ax2.annotate('Source: China Money Network', (0,0), (0, -5), xycoords='axes fraction', textcoords='offset points', color='black', va='top',fontproperties=footnote)

plt.savefig('finally side by side.png')
plt.show()

# %%
def make_pie(sizes, text,colors,labels):
    import matplotlib.pyplot as plt
    import numpy as np

    col = [[i/255. for i in c] for c in colors]

    fig, ax = plt.subplots()
    ax.axis('equal')
    width = 0.35
    kwargs = dict(colors=col, startangle=180)
    outside, _ = ax.pie(sizes, radius=1, pctdistance=1-width/2,labels=labels,**kwargs)
    plt.setp( outside, width=width, edgecolor='white')

    kwargs = dict(size=15, fontweight='bold', va='center')
    ax.text(0, 0, text, ha='center', **kwargs)
    plt.show()

c1 = (226,33,7)
c2 = (60,121,189)

make_pie([257,90], "Gender (AR)",[c1,c2],['M','F'])

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.axis('equal')
width = 0.3

cm = plt.get_cmap("tab20c")
cout = cm(np.arange(3)*4)
pie, _ = ax.pie([120,77,39], radius=1, labels=list("ABC"), colors=cout)
plt.setp( pie, width=width, edgecolor='white')

cin = cm(np.array([1,2,5,6,9,10]))
labels = list(map("".join, zip(list("aabbcc"),map(str, [1,2]*3))))
pie2, _ = ax.pie([60,60,37,40,29,10], radius=1-width, labels=labels,
                                      labeldistance=0.7, colors=cin)
plt.setp( pie2, width=width, edgecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def make_pie(sizes, text,colors,labels, radius=1):
    col = [[i/255 for i in c] for c in colors]

    plt.axis('equal')
    width = 0.35
    kwargs = dict(colors=col, startangle=180)
    outside, _ = plt.pie(sizes, radius=radius, pctdistance=1-width/2,labels=labels,**kwargs)
    plt.setp( outside, width=width, edgecolor='white')

    kwargs = dict(size=20, fontweight='bold', va='center')
    plt.text(0, 0, text, ha='center', **kwargs)

# Group colors
c1 = (226, 33, 7)
c2 = (60, 121, 189)

# Subgroup colors
d1 = (226, 33, 7)
d2 = (60, 121, 189)
d3 = (25, 25, 25)

make_pie([100, 80, 90], "", [d1, d3, d2], ['M', 'N', 'F'], radius=1.2)
make_pie([180, 90], "", [c1, c2], ['M', 'F'], radius=1)
plt.show()

# %%
#https://medium.com/@krishnakummar/donut-chart-with-python-matplotlib-d411033c960b
#https://medium.com/@kvnamipara/a-better-visualisation-of-pie-charts-by-matplotlib-935b7667d77f
